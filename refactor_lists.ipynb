# %%
import json
import stop_lists

list_ = stop_lists.stop_list_dragon_line
for key, stop in list_.items():
    # Create a new dict with "no" first
    list_[key] = {"no": int(key), **stop}

# Print nicely
print(json.dumps(list_, indent=2, ensure_ascii=False))
# Out:
# {
#   "2": {
#     "no": 2,
#     "direction": "Old Town Bus",
#     "index": 56,
#     "lat": 7.886069,
#     "lon": 98.39229,
#     "stop_name_eng": "Queen Sirikit Park",
#     "stop_name_th": "สวนสิริกิติ์"
#   },
#   "3": {
#     "no": 3,
#     "direction": "Old Town Bus",
#     "index": 134,
#     "lat": 7.884223,
#     "lon": 98.39086,
#     "stop_name_eng": "Old Town Intersection",
#     "stop_name_th": "แยกเมืองเก่า"
#   },
#   "4": {
#     "no": 4,
#     "direction": "Old Town Bus",
#     "index": 159,
#     "lat": 7.883601,
#     "lon": 98.39134,
#     "stop_name_eng": "Government Savings Bank",
#     "stop_name_th": "ธนาคารออมสิน"
#   },
#   "5": {
#     "no": 5,
#     "direction": "Old Town Bus",
#     "index": 243,
#     "lat": 7.883132,
#     "lon": 98.39484,
#     "stop_name_eng": "Royal Phuket City Hotel",
#     "stop_name_th": "โรงแรม รอยัล ภูเก็ต ซิตี้"
#   },
#   "6": {
#     "no": 6,
#     "direction": "Old Town Bus",
#     "index": 333,
#     "lat": 7.881669,
# ...
